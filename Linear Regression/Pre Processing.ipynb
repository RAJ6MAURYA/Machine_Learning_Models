# %% [markdown]
# ## data importing and pre-processing

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("House_Price.csv",header=0)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.shape
# Out:
# (506, 19)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
sns.jointplot(x="n_hot_rooms",y="price",data=df)

# %%
sns.jointplot(x="rainfall",y="price",data=df)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
sns.countplot(x="bus_ter",data=df)
# Out:
# <AxesSubplot:xlabel='bus_ter', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# 1. Missing values in n_hos_beds
# 2. Sekwness or outliers in crime rate
# 3. Outliers in n_hot_rooms and railfall
# 4. Bus_ter has only 'Yes' values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
 np.percentile(df.n_hot_rooms,[99])
# Out:
# array([15.39952])

# %%
np.percentile(df.n_hot_rooms,[99])[0]
# Out:
# 15.39952

# %%
uv=np.percentile(df.n_hot_rooms,[99])[0]

# %%
uv
# Out:
# 15.39952

# %%
df[df.n_hot_rooms>uv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
df.n_hot_rooms[df.n_hot_rooms>3*uv]=3*uv
# Out:
# C:\Users\maury\AppData\Local\Temp/ipykernel_19844/3384164456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.n_hot_rooms[df.n_hot_rooms>3*uv]=3*uv

# %%
df.n_hot_rooms[df.n_hot_rooms>3*uv]
# Out:
# Series([], Name: n_hot_rooms, dtype: float64)

# %%
df.n_hot_rooms[df.n_hot_rooms>uv]
# Out:
# 2      46.19856
# 166    15.40000
# 204    15.40000
# 267    15.40000
# 369    15.40000
# 423    46.19856
# Name: n_hot_rooms, dtype: float64

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480     11.19200
# 1   5.12   5.06      22.2       9.14      NO       7.332     12.17280
# 2   5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 3   6.16   5.96      21.3       2.94     YES       9.268     11.26720
# 4   6.37   5.86      21.3       5.33      NO       8.824     11.28960
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
np.percentile(df.rainfall,[1])[0]
# Out:
# 20.0

# %%
lv=np.percentile(df.rainfall,[1])[0]

# %%
lv
# Out:
# 20.0

# %%
df[df.rainfall<lv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         3     YES  0.044019

# %%
df[df.rainfall<0.3*lv]=0.3*lv

# %%
df[df.rainfall<lv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num  age  dist1  dist2  \
# 213    6.0         6.0         6.0       6.0       6.0  6.0    6.0    6.0
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213    6.0    6.0       6.0        6.0     6.0         6.0          6.0
#
#     waterbody  rainfall bus_ter  parks
# 213       6.0         6     6.0    6.0

# %%
sns.jointplot(x="crime_rate",y="price",data=df)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.485178    3.625104   41.068419    0.565586    6.283893   68.522925
# std      9.208147    8.600804    7.035901    0.268358    0.702719   28.240108
# min      5.000000    0.006320    6.000000    0.385000    3.561000    2.900000
# 25%     16.850000    0.082045   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.260420   39.690000    0.538000    6.205000   77.500000
# 75%     25.000000    3.689388   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    6.000000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.975731    3.632885    3.964269    3.623775   21.514032   12.646383
# ...

# %% [markdown]
# ## Missing values in n_hos_beds

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
  df.n_hos_beds=df.n_hos_beds.fillna(df.n_hos_beds.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
sns.jointplot(x="crime_rate",y="price",data=df)

# %%
df.crime_rate=np.log(1+df.crime_rate)

# %%
sns.jointplot(x="crime_rate",y="price",data=df)

# %%
df['avg_dist'] =(df.dist1+df.dist2+df.dist3+df.dist4)/4

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480     11.19200
# 1   5.12   5.06      22.2       9.14      NO       7.332     12.17280
# 2   5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 3   6.16   5.96      21.3       2.94     YES       9.268     11.26720
# 4   6.37   5.86      21.3       5.33      NO       8.824     11.28960
#
#   waterbody  rainfall bus_ter     parks  avg_dist
# 0     River        23     YES  0.049347    4.0875
# ...

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.485178    0.817004   41.068419    0.565586    6.283893   68.522925
# std      9.208147    1.023516    7.035901    0.268358    0.702719   28.240108
# min      5.000000    0.006300    6.000000    0.385000    3.561000    2.900000
# 25%     16.850000    0.078853   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.231444   39.690000    0.538000    6.205000   77.500000
# 75%     25.000000    1.545301   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    6.000000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.975731    3.632885    3.964269    3.623775   21.514032   12.646383
# ...

# %%
del df['dist1']

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.485178    0.817004   41.068419    0.565586    6.283893   68.522925
# std      9.208147    1.023516    7.035901    0.268358    0.702719   28.240108
# min      5.000000    0.006300    6.000000    0.385000    3.561000    2.900000
# 25%     16.850000    0.078853   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.231444   39.690000    0.538000    6.205000   77.500000
# 75%     25.000000    1.545301   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    6.000000    8.780000  100.000000
#
#             dist2       dist3       dist4    teachers   poor_prop  n_hos_beds  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.632885    3.964269    3.623775   21.514032   12.646383    7.896631
# ...

# %%
del df['dist3']

# %%
del df['dist4']

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.485178    0.817004   41.068419    0.565586    6.283893   68.522925
# std      9.208147    1.023516    7.035901    0.268358    0.702719   28.240108
# min      5.000000    0.006300    6.000000    0.385000    3.561000    2.900000
# 25%     16.850000    0.078853   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.231444   39.690000    0.538000    6.205000   77.500000
# 75%     25.000000    1.545301   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    6.000000    8.780000  100.000000
#
#             dist2    teachers   poor_prop  n_hos_beds  n_hot_rooms  \
# count  506.000000  506.000000  506.000000  506.000000   506.000000
# mean     3.632885   21.514032   12.646383    7.896631    12.855700
# ...

# %%
del df['dist2']

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.485178    0.817004   41.068419    0.565586    6.283893   68.522925
# std      9.208147    1.023516    7.035901    0.268358    0.702719   28.240108
# min      5.000000    0.006300    6.000000    0.385000    3.561000    2.900000
# 25%     16.850000    0.078853   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.231444   39.690000    0.538000    6.205000   77.500000
# 75%     25.000000    1.545301   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    6.000000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.514032   12.646383    7.896631    12.855700   39.187747
# ...

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall bus_ter  \
# 0       4.98     YES       5.480     11.19200     River        23     YES
# 1       9.14      NO       7.332     12.17280      Lake        42     YES
# 2       4.03      NO       7.394     46.19856      None        38     YES
# 3       2.94     YES       9.268     11.26720      Lake        45     YES
# 4       5.33      NO       8.824     11.28960      Lake        55     YES
#
#       parks  avg_dist
# 0  0.049347    4.0875
# 1  0.046146    4.9675
# 2  0.045764    4.9675
# ...

# %% [markdown]
# ### bus_ter is not required as it's only taking single value and doesn't provide any insights

# %%
del df['bus_ter']

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.485178    0.817004   41.068419    0.565586    6.283893   68.522925
# std      9.208147    1.023516    7.035901    0.268358    0.702719   28.240108
# min      5.000000    0.006300    6.000000    0.385000    3.561000    2.900000
# 25%     16.850000    0.078853   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.231444   39.690000    0.538000    6.205000   77.500000
# 75%     25.000000    1.545301   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    6.000000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.514032   12.646383    7.896631    12.855700   39.187747
# ...

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98     YES       5.480     11.19200     River        23  0.049347
# 1       9.14      NO       7.332     12.17280      Lake        42  0.046146
# 2       4.03      NO       7.394     46.19856      None        38  0.045764
# 3       2.94     YES       9.268     11.26720      Lake        45  0.047151
# 4       5.33      NO       8.824     11.28960      Lake        55  0.039474
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# 2    4.9675
# 3    6.0650
# 4    6.0625

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   teachers     506 non-null    float64
#  7   poor_prop    506 non-null    float64
#  8   airport      506 non-null    object
#  9   n_hos_beds   506 non-null    float64
#  10  n_hot_rooms  506 non-null    float64
#  11  waterbody    506 non-null    object
#  12  rainfall     506 non-null    int64
#  13  parks        506 non-null    float64
#  14  avg_dist     506 non-null    float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 59.4+ KB

# %%
 df=pd.get_dummies(df)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  ...     parks  avg_dist  airport_6.0  \
# 0       4.98       5.480     11.19200  ...  0.049347    4.0875            0
# 1       9.14       7.332     12.17280  ...  0.046146    4.9675            0
# 2       4.03       7.394     46.19856  ...  0.045764    4.9675            0
# 3       2.94       9.268     11.26720  ...  0.047151    6.0650            0
# 4       5.33       8.824     11.28960  ...  0.039474    6.0625            0
#
#    airport_NO  airport_YES  waterbody_6.0  waterbody_Lake  \
# ...

# %%
del df['airport_6.0']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_NO  airport_YES  waterbody_6.0  waterbody_Lake  \
# 0           0            1              0               0
# ...

# %%
del df['waterbody_6.0']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_NO  airport_YES  waterbody_Lake  waterbody_Lake and River  \
# ...

# %%
del df['airport_NO']

# %%
del df['waterbody_None']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_River
# ...

# %%
df.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.467973   -0.453529 -0.256490
# crime_rate               -0.467973    1.000000    0.632305  0.349297
# resid_area               -0.453529    0.632305    1.000000  0.121218
# air_qual                 -0.256490    0.349297    0.121218  1.000000
# room_num                  0.695520   -0.289235   -0.377833 -0.146637
# age                      -0.366309    0.550812    0.648356  0.225250
# teachers                  0.504678   -0.386321   -0.288490 -0.352044
# poor_prop                -0.734412    0.605467    0.597479  0.217383
# n_hos_beds                0.113278   -0.007220    0.018389 -0.073417
# n_hot_rooms               0.027046    0.049379    0.021280 -0.099255
# rainfall                 -0.034446    0.072766    0.080305 -0.068285
# parks                    -0.095328    0.074701   -0.194107  0.917177
# avg_dist                  0.244524   -0.582911   -0.699926 -0.289825
# ...

# %%
del df['parks']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  \
# 0       4.98       5.480     11.19200        23    4.0875            1
# 1       9.14       7.332     12.17280        42    4.9675            0
# 2       4.03       7.394     46.19856        38    4.9675            0
# 3       2.94       9.268     11.26720        45    6.0650            1
# 4       5.33       8.824     11.28960        55    6.0625            0
#
#    waterbody_Lake  waterbody_Lake and River  waterbody_River
# 0               0                         0                1
# ...

# %%
df.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.467973   -0.453529 -0.256490
# crime_rate               -0.467973    1.000000    0.632305  0.349297
# resid_area               -0.453529    0.632305    1.000000  0.121218
# air_qual                 -0.256490    0.349297    0.121218  1.000000
# room_num                  0.695520   -0.289235   -0.377833 -0.146637
# age                      -0.366309    0.550812    0.648356  0.225250
# teachers                  0.504678   -0.386321   -0.288490 -0.352044
# poor_prop                -0.734412    0.605467    0.597479  0.217383
# n_hos_beds                0.113278   -0.007220    0.018389 -0.073417
# n_hot_rooms               0.027046    0.049379    0.021280 -0.099255
# rainfall                 -0.034446    0.072766    0.080305 -0.068285
# avg_dist                  0.244524   -0.582911   -0.699926 -0.289825
# airport_YES               0.185115   -0.135552   -0.101429 -0.075785
# ...

# %% [markdown]
# # Building simple linear model

# %%
import statsmodels.api as sn

# %% [markdown]
# ## y=B0 +B1x
# ### but statsmodels.api dosn't contain B0 term by default
# #### this is a single variable prediction

# %%
X = sn.add_constant(df['room_num'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
lm = sn.OLS(df['price'],X).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     472.3
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):           2.23e-74
# Time:                        21:19:38   Log-Likelihood:                -1673.6
# No. Observations:                 506   AIC:                             3351.
# Df Residuals:                     504   BIC:                             3360.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.7850      2.652    -13.118      0.000     -39.995     -29.575
# ...

# %% [markdown]
# ## another method to do linear reggression

# %%
from sklearn.linear_model import LinearRegression

# %%
 y = df['price']

# %%
X = df[['room_num']]

# %%
lm2 = LinearRegression()

# %%
lm2.fit(X,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_,lm2.coef_)
# Out:
# -34.7849863690785 [9.11380281]

# %%
help(lm2)
# Out:
# Help on LinearRegression in module sklearn.linear_model._base object:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(*, fit_intercept=True, normalize=False, copy_X=True, n_jobs=None, positive=False)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  normalize : bool, default=False
#  |      This parameter is ignored when ``fit_intercept`` is set to False.
# ...

# %%
lm2.predict(X)
# Out:
# array([25.1382671 , 23.73474147, 30.69768682, 28.99340569, 30.35136231,
#        23.8167657 , 20.00719612, 21.46540457, 16.53483725, 19.9342857 ,
#        23.33373415, 19.97985471, 18.88619838, 19.43302654, 20.77275556,
#        18.38493922, 19.3054333 , 19.80669246, 14.93992176, 17.40976232,
#        15.97889528, 19.57884739, 21.19199049, 18.19354936, 19.20518147,
#        16.24319556, 18.19354936, 20.32617922, 24.40916288, 26.04053358,
#        17.28216908, 20.55402429, 19.44214035, 17.17280345, 20.77275556,
#        19.2872057 , 18.44873584, 18.53076007, 19.58796119, 25.32054316,
#        29.23036456, 26.91545865, 21.43806316, 21.82084288, 20.52668288,
#        16.99964119, 17.94747669, 20.17124457, 14.420435  , 16.27053697,
#        19.56061978, 20.94591781, 24.55498372, 19.87960288, 18.87708457,
#        31.2809702 , 23.38841696, 27.33469358, 21.21933189, 19.23252288,
#        17.53735556, 19.58796119, 24.05372457, 26.84254823, 29.95946879,
# ...

# %%
sns.jointplot(x=df['room_num'],y=df['price'],data=df,kind="reg")

# %% [markdown]
# ## multi variable model

# %%
x_multi= df.drop('price',axis=1)

# %%
x_multi.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0    0.006300       32.31     0.538     6.575  65.2      24.7       4.98
# 1    0.026944       37.07     0.469     6.421  78.9      22.2       9.14
# 2    0.026924       37.07     0.469     7.185  61.1      22.2       4.03
# 3    0.031857       32.18     0.458     6.998  45.8      21.3       2.94
# 4    0.066770       32.18     0.458     7.147  54.2      21.3       5.33
#
#    n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  waterbody_Lake  \
# 0       5.480     11.19200        23    4.0875            1               0
# 1       7.332     12.17280        42    4.9675            0               1
# 2       7.394     46.19856        38    4.9675            0               0
# 3       9.268     11.26720        45    6.0650            1               1
# 4       8.824     11.28960        55    6.0625            0               1
#
#    waterbody_Lake and River  waterbody_River
# ...

# %%
y_multi=df['price']

# %%
y_multi.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: price, dtype: float64

# %% [markdown]
# ## adding constant to the sn model as it doesn't have B0

# %%
x_multi_cons = sn.add_constant(x_multi)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
x_multi_cons.head()
# Out:
#    const  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0    1.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1    1.0    0.026944       37.07     0.469     6.421  78.9      22.2
# 2    1.0    0.026924       37.07     0.469     7.185  61.1      22.2
# 3    1.0    0.031857       32.18     0.458     6.998  45.8      21.3
# 4    1.0    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  \
# 0       4.98       5.480     11.19200        23    4.0875            1
# 1       9.14       7.332     12.17280        42    4.9675            0
# 2       4.03       7.394     46.19856        38    4.9675            0
# 3       2.94       9.268     11.26720        45    6.0650            1
# 4       5.33       8.824     11.28960        55    6.0625            0
#
#    waterbody_Lake  waterbody_Lake and River  waterbody_River
# 0               0                         0                1
# ...

# %%
lm_multi = sn.OLS(y_multi,x_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.715
# Model:                            OLS   Adj. R-squared:                  0.707
# Method:                 Least Squares   F-statistic:                     82.04
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):          5.16e-123
# Time:                        21:19:41   Log-Likelihood:                -1523.1
# No. Observations:                 506   AIC:                             3078.
# Df Residuals:                     490   BIC:                             3146.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # linear regression using sklearn package

# %%
lm3=LinearRegression()

# %%
lm3.fit(x_multi,y_multi)
# Out:
# LinearRegression()

# %%
print(lm3.intercept_,lm3.coef_)
# Out:
# -7.436124365718278 [-0.40402808 -0.12686404 -1.91725679  4.12586203 -0.01788127  0.84275653
#  -0.58215896  0.37664469  0.08914503  0.01121006 -1.03799326  1.09789369
#   0.37500664 -0.6740188  -0.33387485]

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # test_train data split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_multi, y_multi, test_size = 0.2, random_state=0)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (404, 15) (102, 15) (404,) (102,)

# %%
lm_a = LinearRegression()

# %%
lm_a.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_a = lm_a.predict(x_test)

# %%
y_train_a = lm_a.predict(x_train)

# %% [markdown]
# ## checking the R^2 value

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_test_a)
# Out:
# -0.24286154193723908

# %%
r2_score(y_train,y_train_a)
# Out:
# 0.7564636279782837

# %%
from sklearn import preprocessing

# %%
scaler = preprocessing.StandardScaler().fit(x_train)

# %%
x_train_s = scaler.transform(x_train)

# %%
x_test_s=scaler.transform(x_test)

# %%
from sklearn.linear_model import Ridge

# %%
lm_r = Ridge(alpha = 0.5)
lm_r.fit(x_train_s, y_train)
# Out:
# Ridge(alpha=0.5)

# %%
r2_score(y_test,lm_r.predict(x_test_s))
# Out:
# -0.22939434192973973

# %%
from sklearn.model_selection import validation_curve

# %%
param_range = np.logspace(-2,8,100 )

# %%
param_range
# Out:
# array([1.00000000e-02, 1.26185688e-02, 1.59228279e-02, 2.00923300e-02,
#        2.53536449e-02, 3.19926714e-02, 4.03701726e-02, 5.09413801e-02,
#        6.42807312e-02, 8.11130831e-02, 1.02353102e-01, 1.29154967e-01,
#        1.62975083e-01, 2.05651231e-01, 2.59502421e-01, 3.27454916e-01,
#        4.13201240e-01, 5.21400829e-01, 6.57933225e-01, 8.30217568e-01,
#        1.04761575e+00, 1.32194115e+00, 1.66810054e+00, 2.10490414e+00,
#        2.65608778e+00, 3.35160265e+00, 4.22924287e+00, 5.33669923e+00,
#        6.73415066e+00, 8.49753436e+00, 1.07226722e+01, 1.35304777e+01,
#        1.70735265e+01, 2.15443469e+01, 2.71858824e+01, 3.43046929e+01,
#        4.32876128e+01, 5.46227722e+01, 6.89261210e+01, 8.69749003e+01,
#        1.09749877e+02, 1.38488637e+02, 1.74752840e+02, 2.20513074e+02,
#        2.78255940e+02, 3.51119173e+02, 4.43062146e+02, 5.59081018e+02,
#        7.05480231e+02, 8.90215085e+02, 1.12332403e+03, 1.41747416e+03,
# ...

# %%
train_scores, test_scores = validation_curve(Ridge(),x_train_s,y_train,"alpha",param_range,scoring='r2')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass param_name=alpha, param_range=[1.00000000e-02 1.26185688e-02 1.59228279e-02 2.00923300e-02
#  2.53536449e-02 3.19926714e-02 4.03701726e-02 5.09413801e-02
#  6.42807312e-02 8.11130831e-02 1.02353102e-01 1.29154967e-01
#  1.62975083e-01 2.05651231e-01 2.59502421e-01 3.27454916e-01
#  4.13201240e-01 5.21400829e-01 6.57933225e-01 8.30217568e-01
#  1.04761575e+00 1.32194115e+00 1.66810054e+00 2.10490414e+00
#  2.65608778e+00 3.35160265e+00 4.22924287e+00 5.33669923e+00
#  6.73415066e+00 8.49753436e+00 1.07226722e+01 1.35304777e+01
#  1.70735265e+01 2.15443469e+01 2.71858824e+01 3.43046929e+01
#  4.32876128e+01 5.46227722e+01 6.89261210e+01 8.69749003e+01
#  1.09749877e+02 1.38488637e+02 1.74752840e+02 2.20513074e+02
#  2.78255940e+02 3.51119173e+02 4.43062146e+02 5.59081018e+02
#  7.05480231e+02 8.90215085e+02 1.12332403e+03 1.41747416e+03
# ...

# %%
print(train_scores)
print(test_scores)
# Out:
# [[7.49308200e-01 7.62593475e-01 7.52614713e-01 7.82225913e-01
#   7.45875653e-01]
#  [7.49308200e-01 7.62593475e-01 7.52614713e-01 7.82225913e-01
#   7.45875653e-01]
#  [7.49308199e-01 7.62593474e-01 7.52614712e-01 7.82225912e-01
#   7.45875652e-01]
#  [7.49308197e-01 7.62593473e-01 7.52614711e-01 7.82225911e-01
#   7.45875650e-01]
#  [7.49308195e-01 7.62593471e-01 7.52614709e-01 7.82225909e-01
#   7.45875648e-01]
#  [7.49308191e-01 7.62593467e-01 7.52614706e-01 7.82225907e-01
#   7.45875645e-01]
#  [7.49308185e-01 7.62593462e-01 7.52614701e-01 7.82225903e-01
#   7.45875640e-01]
#  [7.49308175e-01 7.62593454e-01 7.52614694e-01 7.82225896e-01
#   7.45875632e-01]
#  [7.49308159e-01 7.62593441e-01 7.52614682e-01 7.82225886e-01
#   7.45875619e-01]
#  [7.49308134e-01 7.62593421e-01 7.52614663e-01 7.82225869e-01
#   7.45875599e-01]
#  [7.49308095e-01 7.62593388e-01 7.52614633e-01 7.82225843e-01
#   7.45875566e-01]
#  [7.49308032e-01 7.62593336e-01 7.52614584e-01 7.82225801e-01
# ...

# %%
train_mean = np.mean(train_scores, axis =1)

# %%
test_mean = np.mean(test_scores,axis=1)

# %%
train_mean
# Out:
# array([7.58523591e-01, 7.58523590e-01, 7.58523590e-01, 7.58523588e-01,
#        7.58523586e-01, 7.58523583e-01, 7.58523578e-01, 7.58523570e-01,
#        7.58523557e-01, 7.58523537e-01, 7.58523505e-01, 7.58523454e-01,
#        7.58523372e-01, 7.58523242e-01, 7.58523036e-01, 7.58522709e-01,
#        7.58522189e-01, 7.58521365e-01, 7.58520060e-01, 7.58517996e-01,
#        7.58514735e-01, 7.58509597e-01, 7.58501519e-01, 7.58488860e-01,
#        7.58469102e-01, 7.58438406e-01, 7.58390994e-01, 7.58318262e-01,
#        7.58207594e-01, 7.58040793e-01, 7.57792089e-01, 7.57425705e-01,
#        7.56892964e-01, 7.56128877e-01, 7.55048074e-01, 7.53539778e-01,
#        7.51461458e-01, 7.48630954e-01, 7.44817580e-01, 7.39733915e-01,
#        7.33031575e-01, 7.24305378e-01, 7.13110098e-01, 6.98991577e-01,
#        6.81529365e-01, 6.60383127e-01, 6.35332823e-01, 6.06305852e-01,
#        5.73392182e-01, 5.36855411e-01, 4.97147086e-01, 4.54921581e-01,
# ...

# %%
max(test_mean)
# Out:
# 0.7386140686477374

# %%
sns.jointplot(x=np.log(param_range),y=(test_mean))

# %%
np.where(test_mean==max(test_mean))
# Out:
# (array([31], dtype=int64),)

# %%
param_range[31]
# Out:
# 13.530477745798061

# %%
lm_r_best = Ridge(alpha=param_range[31])

# %%
lm_r_best.fit(x_train_s,y_train)
# Out:
# Ridge(alpha=13.530477745798061)

# %%
r2_score(y_test,lm_r_best.predict(x_test_s))
# Out:
# 0.024052632173025446

# %%
r2_score(y_train,lm_r_best.predict(x_train_s))
# Out:
# 0.7557314167193125

# %% [markdown]
# # lasso

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19844/3572195617.py in <module>
# ----> 1 lm_l = Lasso(alpha = 0.4)
#
# NameError: name 'Lasso' is not defined
